# %%
import pandas as pd
import pylab as plt
import seaborn as sns
import numpy as np

# %%
test=pd.read_csv('../data/salaries_nor.csv', encoding ='latin')

# %%
test.head()
# Out:
#    Unnamed: 0  work_year  experience_level  employment_type  job_title  \
# 0           0   0.859977          0.843493         0.027854  -0.383744
# 1           1   0.859977          0.843493         0.027854  -0.383744
# 2           2  -0.586023         -0.124371         0.027854  -1.476392
# 3           3  -0.586023         -0.124371        -8.425971   1.404225
# 4           4  -0.586023         -0.124371         0.027854  -0.383744
#
#      salary  salary_currency  employee_residence  remote_ratio  \
# 0 -0.119080         0.679021            0.799156      0.714862
# 1 -0.122482         0.679021            0.799156      0.714862
# 2 -0.145164         0.679021            0.799156      0.714862
# 3 -0.034995         0.679021            0.799156      0.714862
# 4 -0.195712        -1.378378            0.361005     -1.743615
#
#    company_location  company_size
# 0          0.756121      0.289918
# 1          0.756121      0.289918
# 2          0.756121      0.289918
# ...
