# %%
import pandas as pd
import pylab as plt
import seaborn as sns
import numpy as np

# %%
salaries=pd.read_csv('../data/salaries_data.csv', encoding ='latin')
testeo=pd.read_csv('../data/testeo.csv',encoding='latin')

# %% [markdown]
# ### Define variable y and remove it from the DF

# %%
y=salaries['salary_in_usd']

# %%
salaries2=salaries.drop(columns=['salary_in_usd'])

# %%
salaries2.tail()
# Out:
#      work_year experience_level employment_type  \
# 495       2022               SE              FT
# 496       2021               EN              FT
# 497       2022               SE              FT
# 498       2021               MI              FT
# 499       2021               EN              FT
#
#                              job_title  salary salary_currency  \
# 495                      Data Engineer  100000             USD
# 496                  Big Data Engineer  435000             INR
# 497                     Data Architect   90700             USD
# 498                      Data Engineer   60000             GBP
# 499  Computer Vision Software Engineer   70000             USD
#
#     employee_residence  remote_ratio company_location company_size
# 495                 US           100               US            M
# 496                 IN             0               CH            L
# 497                 CA           100               CA            M
# 498                 GB           100               GB            L
# 499                 US           100               US            M

# %%
salaries2.shape
# Out:
# (500, 10)

# %% [markdown]
# ### Concatenate salaries and testeo to apply changes to both at the same time

# %%
salaries3= pd.concat([salaries2,testeo])

salaries.head()
# Out:
#    work_year experience_level employment_type        job_title  salary  \
# 0       2022               SE              FT    Data Engineer  140250
# 1       2022               SE              FT    Data Engineer  135000
# 2       2021               MI              FT  BI Data Analyst  100000
# 3       2021               MI              CT      ML Engineer  270000
# 4       2021               MI              FT    Data Engineer   22000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         140250                 US           100
# 1             USD         135000                 US           100
# 2             USD         100000                 US           100
# 3             USD         270000                 US           100
# 4             EUR          26005                 RO             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            L
# 4               US            L

# %% [markdown]
# #### Drop salary and salary currency because it tricks the model and the error

# %%
salaries3=salaries3.drop(columns=['salary','salary_currency'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/2z/3qxl1g8j49s520l3b9w9y4hr0000gn/T/ipykernel_36874/4229665313.py in <module>
# ----> 1 salaries3=salaries3.drop(columns=['salary','salary_currency'])
#
# /opt/anaconda3/envs/clase/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/envs/clase/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /opt/anaconda3/envs/clase/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /opt/anaconda3/envs/clase/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /opt/anaconda3/envs/clase/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['salary' 'salary_currency'] not found in axis"

# %%
salaries3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 607 entries, 0 to 106
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   employee_residence  607 non-null    object
#  5   remote_ratio        607 non-null    int64
#  6   company_location    607 non-null    object
#  7   company_size        607 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 42.7+ KB

# %%
salaries3.shape
# Out:
# (607, 8)

# %%
salaries3=salaries3.reset_index().drop('index', axis=1)

# %%
salaries3.tail()
# Out:
#      work_year experience_level employment_type       job_title  \
# 602       2022               SE              FT    Data Analyst
# 603       2022               SE              FT  Data Architect
# 604       2022               SE              FT  Data Scientist
# 605       2022               EN              FT    Data Analyst
# 606       2022               SE              FT    Data Analyst
#
#     employee_residence  remote_ratio company_location company_size
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US           100               US            M
# 605                 CA             0               CA            M
# 606                 US             0               US            M

# %% [markdown]
# ### Examinate the columns and data

# %%
salaries3.experience_level.value_counts()
# Out:
# SE    280
# MI    213
# EN     88
# EX     26
# Name: experience_level, dtype: int64

# %%
salaries3['job_title'].replace(['Computer Vision Software Engineer','Head of Data Science' ],['Computer Vision Engineer','Director of Data Science' ], inplace=True)

# %%
a=salaries3.groupby('company_location' ).agg({'remote_ratio':'mean'})
a
# Out:
#                   remote_ratio
# company_location
# AE                   66.666667
# AS                  100.000000
# AT                   25.000000
# AU                   83.333333
# BE                   75.000000
# BR                   33.333333
# CA                   75.000000
# CH                    0.000000
# CL                  100.000000
# CN                    0.000000
# CO                   50.000000
# CZ                   75.000000
# DE                   62.500000
# DK                   66.666667
# DZ                   50.000000
# EE                  100.000000
# ES                   92.857143
# FR                   50.000000
# GB                   47.872340
# GR                   77.272727
# HN                    0.000000
# HR                  100.000000
# HU                   50.000000
# IE                  100.000000
# IL                  100.000000
# IN                   60.416667
# IQ                   50.000000
# IR                  100.000000
# IT                   50.000000
# JP                   41.666667
# KE                  100.000000
# LU                   83.333333
# MD                    0.000000
# MT                   50.000000
# MX                   33.333333
# MY                  100.000000
# NG                  100.000000
# NL                   87.500000
# NZ                   50.000000
# PK                   33.333333
# PL                  100.000000
# PT                   50.000000
# RO                   50.000000
# RU                   25.000000
# SG                   50.000000
# SI                   75.000000
# TR                   50.000000
# UA                  100.000000
# US                   77.746479
# VN                    0.000000

# %%
salaries3.employee_residence.value_counts()
# Out:
# US    332
# GB     44
# IN     30
# CA     29
# DE     25
# FR     18
# ES     15
# GR     13
# JP      7
# BR      6
# PT      6
# PK      6
# NL      5
# PL      4
# IT      4
# RU      4
# AU      3
# AE      3
# VN      3
# AT      3
# TR      3
# SG      2
# HU      2
# DK      2
# RO      2
# NG      2
# MX      2
# SI      2
# BE      2
# IE      1
# AR      1
# CO      1
# IQ      1
# HR      1
# PH      1
# CN      1
# MD      1
# LU      1
# MT      1
# BO      1
# MY      1
# HN      1
# UA      1
# NZ      1
# RS      1
# IR      1
# DZ      1
# KE      1
# CH      1
# PR      1
# CL      1
# CZ      1
# EE      1
# HK      1
# BG      1
# JE      1
# TN      1
# Name: employee_residence, dtype: int64

# %%
salaries3.company_location.value_counts()
# Out:
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# PT      4
# AT      4
# PL      4
# NL      4
# PK      3
# DK      3
# AU      3
# BR      3
# AE      3
# TR      3
# LU      3
# MX      3
# CH      2
# IT      2
# CZ      2
# RU      2
# BE      2
# SI      2
# NG      2
# CN      2
# MT      1
# HN      1
# IL      1
# RO      1
# SG      1
# CO      1
# IQ      1
# HR      1
# NZ      1
# HU      1
# IR      1
# DZ      1
# EE      1
# UA      1
# CL      1
# KE      1
# VN      1
# IE      1
# AS      1
# MD      1
# MY      1
# Name: company_location, dtype: int64

# %%
salaries3.job_title.value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Director of Data Science                     11
# Computer Vision Engineer                      9
# Machine Learning Scientist                    8
# Big Data Engineer                             8
# Data Science Consultant                       7
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Analytics Manager                        7
# BI Data Analyst                               6
# Lead Data Engineer                            6
# ML Engineer                                   6
# Business Data Analyst                         5
# Applied Data Scientist                        5
# Head of Data                                  5
# Data Engineering Manager                      5
# Data Analytics Engineer                       4
# Applied Machine Learning Scientist            4
# Analytics Engineer                            4
# Lead Data Analyst                             3
# Data Science Engineer                         3
# Machine Learning Infrastructure Engineer      3
# Lead Data Scientist                           3
# Principal Data Engineer                       3
# Machine Learning Developer                    3
# Director of Data Engineering                  2
# Financial Data Analyst                        2
# Product Data Analyst                          2
# ETL Developer                                 2
# Cloud Data Engineer                           2
# Principal Data Analyst                        2
# Lead Machine Learning Engineer                1
# Big Data Architect                            1
# Marketing Data Analyst                        1
# Data Analytics Lead                           1
# Data Specialist                               1
# Finance Data Analyst                          1
# Head of Machine Learning                      1
# Staff Data Scientist                          1
# 3D Computer Vision Researcher                 1
# Machine Learning Manager                      1
# NLP Engineer                                  1
# Name: job_title, dtype: int64

# %%
#pd.set_option('display.max_rows', 500)
#salaries3.groupby(['company_location', 'job_title']).agg({'salary':['mean','max','min','count']})

# %%
# buscando colinealidad

plt.figure(figsize=(15,12))

sns.set(style='white')

mask=np.triu(np.ones_like(salaries.corr(), dtype=bool))

cmap=sns.diverging_palette(0, 10, as_cmap=True)


sns.heatmap(salaries.corr(),
           mask=mask,
          cmap=cmap,
          center=0,
          square=True,
          annot=True,
          linewidths=0.5,
          cbar_kws={'shrink': 0.5});

# %%
salaries3.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
for c in salaries3.columns:       #valores unicos de cada columna
    
    columna=c
    
    print(c,'- valores únicos: ',len(salaries3[columna].unique()))
# Out:
# work_year - valores únicos:  3
# experience_level - valores únicos:  4
# employment_type - valores únicos:  4
# job_title - valores únicos:  48
# employee_residence - valores únicos:  57
# remote_ratio - valores únicos:  3
# company_location - valores únicos:  50
# company_size - valores únicos:  3

# %%
salaries3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   employee_residence  607 non-null    object
#  5   remote_ratio        607 non-null    int64
#  6   company_location    607 non-null    object
#  7   company_size        607 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 38.1+ KB

# %% [markdown]
# ### Apply Label Encoder to all the object columns

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

salaries3.experience_level=LabelEncoder().fit_transform(salaries3.experience_level)

salaries3.tail()
# Out:
#      work_year  experience_level employment_type       job_title  \
# 602       2022                 3              FT    Data Analyst
# 603       2022                 3              FT  Data Architect
# 604       2022                 3              FT  Data Scientist
# 605       2022                 0              FT    Data Analyst
# 606       2022                 3              FT    Data Analyst
#
#     employee_residence  remote_ratio company_location company_size
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US           100               US            M
# 605                 CA             0               CA            M
# 606                 US             0               US            M

# %%
salaries3.employment_type=LabelEncoder().fit_transform(salaries3.employment_type)

salaries3.head()
# Out:
#    work_year  experience_level  employment_type        job_title  \
# 0       2022                 3                2    Data Engineer
# 1       2022                 3                2    Data Engineer
# 2       2021                 2                2  BI Data Analyst
# 3       2021                 2                0      ML Engineer
# 4       2021                 2                2    Data Engineer
#
#   employee_residence  remote_ratio company_location company_size
# 0                 US           100               US            M
# 1                 US           100               US            M
# 2                 US           100               US            M
# 3                 US           100               US            L
# 4                 RO             0               US            L

# %%
salaries3.job_title=LabelEncoder().fit_transform(salaries3.job_title)

salaries3.head()
# Out:
#    work_year  experience_level  employment_type  job_title employee_residence  \
# 0       2022                 3                2         16                 US
# 1       2022                 3                2         16                 US
# 2       2021                 2                2          5                 US
# 3       2021                 2                0         34                 US
# 4       2021                 2                2         16                 RO
#
#    remote_ratio company_location company_size
# 0           100               US            M
# 1           100               US            M
# 2           100               US            M
# 3           100               US            L
# 4             0               US            L

# %%
salaries3.employee_residence=LabelEncoder().fit_transform(salaries3.employee_residence)

salaries3.head()
# Out:
#    work_year  experience_level  employment_type  job_title  \
# 0       2022                 3                2         16
# 1       2022                 3                2         16
# 2       2021                 2                2          5
# 3       2021                 2                0         34
# 4       2021                 2                2         16
#
#    employee_residence  remote_ratio company_location company_size
# 0                  55           100               US            M
# 1                  55           100               US            M
# 2                  55           100               US            M
# 3                  55           100               US            L
# 4                  47             0               US            L

# %%
salaries3.company_location=LabelEncoder().fit_transform(salaries3.company_location)

salaries3.head()
# Out:
#    work_year  experience_level  employment_type  job_title  \
# 0       2022                 3                2         16
# 1       2022                 3                2         16
# 2       2021                 2                2          5
# 3       2021                 2                0         34
# 4       2021                 2                2         16
#
#    employee_residence  remote_ratio  company_location company_size
# 0                  55           100                48            M
# 1                  55           100                48            M
# 2                  55           100                48            M
# 3                  55           100                48            L
# 4                  47             0                48            L

# %%
salaries3.company_size=LabelEncoder().fit_transform(salaries3.company_size)

salaries3.tail()
# Out:
#      work_year  experience_level  employment_type  job_title  \
# 602       2022                 3                2         11
# 603       2022                 3                2         15
# 604       2022                 3                2         21
# 605       2022                 0                2         11
# 606       2022                 3                2         11
#
#      employee_residence  remote_ratio  company_location  company_size
# 602                  55           100                48             1
# 603                  55           100                48             1
# 604                  55           100                48             1
# 605                   8             0                 6             1
# 606                  55             0                48             1

# %% [markdown]
# ### Apply StandarScaler to normalize the data

# %%
from sklearn.preprocessing import StandardScaler
ss=pd.DataFrame(StandardScaler().fit_transform(salaries3._get_numeric_data()),  # standardize numeric columns
         columns=salaries3._get_numeric_data().columns)

# %%
ss.tail()
# Out:
#      work_year  experience_level  employment_type  job_title  \
# 602   0.859977          0.843493         0.027854  -0.880402
# 603   0.859977          0.843493         0.027854  -0.483076
# 604   0.859977          0.843493         0.027854   0.112914
# 605   0.859977         -2.060100         0.027854  -0.880402
# 606   0.859977          0.843493         0.027854  -0.880402
#
#      employee_residence  remote_ratio  company_location  company_size
# 602            0.799156      0.714862          0.756121      0.289918
# 603            0.799156      0.714862          0.756121      0.289918
# 604            0.799156      0.714862          0.756121      0.289918
# 605           -1.774979     -1.743615         -1.865824      0.289918
# 606            0.799156     -1.743615          0.756121      0.289918

# %%
plt.figure(figsize=(15,12))

sns.set(style='white')

mask=np.triu(np.ones_like(ss.corr(), dtype=bool))

cmap=sns.diverging_palette(0, 10, as_cmap=True)


sns.heatmap(ss.corr(),
           mask=mask,
          cmap=cmap,
          center=0,
          square=True,
          annot=True,
          linewidths=0.5,
          cbar_kws={'shrink': 0.5});

# %% [markdown]
# ### Split the DF after the transformations to Salaries and Testeo

# %%
salaries_nor=ss[0:500]
salaries_nor.tail()
# Out:
#      work_year  experience_level  employment_type  job_title  \
# 495   0.859977          0.843493         0.027854  -0.383744
# 496  -0.586023         -2.060100         0.027854  -1.277728
# 497   0.859977          0.843493         0.027854  -0.483076
# 498  -0.586023         -0.124371         0.027854  -0.383744
# 499  -0.586023         -2.060100         0.027854  -0.979734
#
#      employee_residence  remote_ratio  company_location  company_size
# 495            0.799156      0.714862          0.756121      0.289918
# 496           -0.734371     -1.743615         -1.803397     -1.240346
# 497           -1.774979      0.714862         -1.865824      0.289918
# 498           -1.117753      0.714862         -1.116697     -1.240346
# 499            0.799156      0.714862          0.756121      0.289918

# %%
salaries_nor.to_csv('../data/salaries_nor.csv')

# %%
testeo_nor=ss[500:]
testeo_nor
testeo_nor=testeo_nor.reset_index().drop('index', axis=1)
testeo_nor.head()
# Out:
#    work_year  experience_level  employment_type  job_title  \
# 0  -2.032024          0.843493         0.027854   1.900883
# 1  -2.032024         -0.124371         0.027854   1.006898
# 2  -2.032024         -0.124371         0.027854  -0.880402
# 3  -2.032024         -0.124371         0.027854   1.602888
# 4  -2.032024         -0.124371         0.027854   2.496872
#
#    employee_residence  remote_ratio  company_location  company_size
# 0           -0.460527     -1.743615         -0.429997      1.820182
# 1            0.799156      0.714862          0.756121     -1.240346
# 2            0.799156      0.714862          0.756121     -1.240346
# 3           -1.610673     -1.743615         -1.678542      0.289918
# 4           -0.734371      0.714862         -0.679706     -1.240346

# %%
testeo_nor.to_csv('../data/testeo_nor.csv')

# %%
X=salaries_nor

# %%
X.shape, y.shape
# Out:
# ((500, 8), (500,))

# %% [markdown]
# ### Preparation for testing

# %%
from sklearn.model_selection import train_test_split as tts 
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.ensemble import RandomForestClassifier as RFC

from sklearn.model_selection import GridSearchCV        # por fuerza bruta
from sklearn.model_selection import RandomizedSearchCV

X_train, X_test, y_train, y_test = tts(X,y,test_size=0.2, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((400, 8), (100, 8), (400,), (100,))

# %%
X_train, X_test, y_train, y_test = tts(X, y,test_size=0.2,random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((400, 8), (100, 8), (400,), (100,))

# %% [markdown]
# ### Models evaluation

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier, LazyRegressor

# %%
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
models

# %% [markdown]
# ### Applying RFR model

# %%
rfr=RFR()

rfr.fit(X_train, y_train)

y_pred=rfr.predict(X_test)

train_score=rfr.score(X_train, y_train)    # R2
test_score=rfr.score(X_test, y_test)

print (train_score, test_score)
# Out:
# 0.8519980983141374 0.1941420398523015

# %%
y_pred=rfr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error as mse

# %%
mse(y_test, y_pred, squared=False)
# Out:
# 56153.11941651273

# %% [markdown]
# #### Test it vs the Testeo

# %%
y_pred1=rfr.predict(testeo_nor)

# %%
y_pred1
# Out:
# array([123048.657     , 260024.75      , 119322.089     ,  90895.88      ,
#         40616.48      , 101628.86      ,  62170.30133333,  57306.38333333,
#         42410.54      , 147269.84285714,  62575.09      , 155072.75238095,
#         79574.99711905,  29154.2535    ,  80705.335     ,  55616.85666667,
#         74325.24      , 163758.80952381,  66599.22333333,  70144.26      ,
#        116698.584     ,  63569.66333333,  73210.19      , 197589.5       ,
#         33599.36      ,  37642.502     ,  78428.61904762, 237490.82      ,
#         31254.4225    ,  44627.26      ,  36759.89      , 104982.53823954,
#         64135.47833333,  61962.952     ,  80651.25      ,  81545.14333333,
#        179047.50952381,  82137.72666667,  83979.10666667, 214730.        ,
#         44179.91      ,  29762.48      , 116049.89852381, 161178.10225225,
#         90037.61904762, 215786.95      , 127816.73526984,  74432.89      ,
#        104982.53823954,  49323.435     ,  95077.30952381,  54094.229     ,
#        122656.19466667, 161593.45773757, 110382.65595421,  90199.19371429,
#        161495.08732819, 145839.05840816, 107167.90168462, 140091.67641995,
#        107167.90168462, 254665.4047619 , 140091.67641995, 142700.35901154,
#        176967.55433333, 223105.39584802, 223105.39584802, 140091.67641995,
#        101627.47039866,  85185.13666667, 210330.74130952, 169995.42135642,
#        109795.32095421,  76419.08380952, 102859.19      , 128698.282     ,
#         66378.43135714,  77717.30466667,  71487.331     , 148011.02      ,
#         41541.158     ,  46619.83      , 287602.16666667, 301580.92571429,
#        124103.64081983,  60193.96471429,  60193.96471429, 161495.08732819,
#        140091.67641995,  71371.57      ,  87329.48      ,  41567.2       ,
#         83706.17666667,  44734.91      , 140091.67641995, 301836.3       ,
#         54010.22      ,  85529.98035714,  79762.41      , 263225.03292063,
#        140091.67641995, 107167.90168462, 107167.90168462, 223105.39584802,
#        161495.08732819,  69589.36      , 101627.47039866])

# %% [markdown]
# #### Create a DF from an array

# %%
prueba = pd.DataFrame(y_pred1, columns = ['salary_in_usd'])
prueba
# Out:
#      salary_in_usd
# 0    123048.657000
# 1    260024.750000
# 2    119322.089000
# 3     90895.880000
# 4     40616.480000
# ..             ...
# 102  107167.901685
# 103  223105.395848
# 104  161495.087328
# 105   69589.360000
# 106  101627.470399
#
# [107 rows x 1 columns]

# %%
prueba.to_csv('../data/prueba.csv',index_label='id')

# %% [markdown]
# ### Apply SVC method

# %%
from sklearn.svm import SVC

svc=SVC(probability=True)

svc.fit(X_train, y_train)

y_prob=svc.predict_proba(X_test)

# %%
mse(y_test, y_pred, squared=False)
# Out:
# 57423.051728395556

# %%
y_pred2=svc.predict(testeo_nor)

# %%
prueba2 = pd.DataFrame(y_pred2, columns = ['salary_in_usd'])
prueba2
# Out:
#      salary_in_usd
# 0           100000
# 1           150000
# 2           150000
# 3           100000
# 4           100000
# ..             ...
# 102          90320
# 103         140000
# 104         140000
# 105          65438
# 106         120000
#
# [107 rows x 1 columns]

# %%
prueba2.to_csv('../data/prueba2.csv',index_label='id')
